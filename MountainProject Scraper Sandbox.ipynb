# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

route_page = 'https://www.mountainproject.com/route-guide'
page = urlopen(route_page)
soup = BeautifulSoup(page,'html.parser')

# %%
#print out route directory
content = soup.find_all('div',class_='clearfix')
for c in content:
    curr = c.find_all('a')
    for cc in curr:
        print(cc.get_text())
# Out:
# Alabama
# Sand Rock
# Jamestown
# Palisades Park
# Alaska
# Anchorage & South Central Ice Climbing
# Denali National Park
# Seward Highway
# Arizona
# Cochise Stronghold
# Sedona Area
# Paradise Forks
# Winslow Wall
# Mount Lemmon (Santa Catalina Mountains)
# Arkansas
# Sam's Throne & Surroundings
# Horseshoe Canyon Ranch
# California
# Joshua Tree National Park
# Tahquitz & Suicide Rocks
# High Sierra
# Sierra Eastside
# Lake Tahoe
# Yosemite National Park
# The Needles / Kern River
# Owens River Gorge
# Southern Sierra
# Lover's Leap
# Colorado
# Boulder Canyon
# Lumpy Ridge
# Eldorado Canyon SP
# Shelf Road
# Rifle Mountain Park
# RMNP - Rock
# Alpine Rock
# Flatirons
# South Platte
# Grand Junction Area
# Gunnison
# CO Ice & Mixed
# Connecticut
# Central Valley
# CT Bouldering
# Delaware
# Florida
# Georgia
# Lost Wall
# Mount Yonah
# Hawaii
# Mokule'ia Wall
# Idaho
# City of Rocks
# Castle Rocks
# Massacre Rocks
# The Sawtooth Range
# The Fins
# Illinois
# *Jackson Falls
# ...

# %%
#print out only states and continents
content = soup.find_all('div',class_='mb-half')
for c in content:
    curr = c.find('a')
    currtext = curr.get_text()
    if currtext == '* In Progress':
        continue
    else:
        print(curr.get_text(),curr['href'])
# Out:
# Alabama https://www.mountainproject.com/area/105905173/alabama
# Alaska https://www.mountainproject.com/area/105909311/alaska
# Arizona https://www.mountainproject.com/area/105708962/arizona
# Arkansas https://www.mountainproject.com/area/105901027/arkansas
# California https://www.mountainproject.com/area/105708959/california
# Colorado https://www.mountainproject.com/area/105708956/colorado
# Connecticut https://www.mountainproject.com/area/105806977/connecticut
# Delaware https://www.mountainproject.com/area/106861605/delaware
# Florida https://www.mountainproject.com/area/111721391/florida
# Georgia https://www.mountainproject.com/area/105897947/georgia
# Hawaii https://www.mountainproject.com/area/106316122/hawaii
# Idaho https://www.mountainproject.com/area/105708958/idaho
# Illinois https://www.mountainproject.com/area/105911816/illinois
# Indiana https://www.mountainproject.com/area/112389571/indiana
# Iowa https://www.mountainproject.com/area/106092653/iowa
# ...

# %%
import time

#for state of Alamaba and Alaska, print out all climbing regions
content = soup.find_all('div',class_='mb-half')
counter = 0
stop = 1
for c in content:
    if counter > stop:
        break
    else:
        curr = c.find('a')
        state_link = curr['href']
        state_page = urlopen(state_link)
        state_soup = BeautifulSoup(state_page,'html.parser')
        
        #get climbing regions within the state
        regions_content = state_soup.find_all('div',class_='lef-nav-row')
        #print(regions_content)
        
        state_name = state_soup.find('h1').get_text()
        print(state_name)
        for rc in regions_content:
            curr_region = rc.find('a')
            curr_region_text = curr_region.get_text()
            print(curr_region_text,curr_region['href'])
            
    counter += 1
    time.sleep(1)
# Out:
#     Alabama Climbing
#
#
# BankHead Forest/ Thompson Creek Trail https://www.mountainproject.com/area/107605102/bankhead-forest-thompson-creek-trail
# Bankhead Forest/Ship Rock https://www.mountainproject.com/area/106248455/bankhead-forestship-rock
# Cherokee Bluffs https://www.mountainproject.com/area/106833394/cherokee-bluffs
# Chewacla State Park https://www.mountainproject.com/area/109749052/chewacla-state-park
# Colbert Heights https://www.mountainproject.com/area/106222485/colbert-heights
# Coosa Slabs https://www.mountainproject.com/area/106087709/coosa-slabs
# Dumps, The https://www.mountainproject.com/area/110705691/the-dumps
# Fort Rucker Climbing Wall https://www.mountainproject.com/area/114296768/fort-rucker-climbing-wall
# Griffin Falls https://www.mountainproject.com/area/105923472/griffin-falls
# Gulf State Park-Boulder Park https://www.mountainproject.com/area/114570504/gulf-state-park-boulder-park
# ...

# %%
#for state of Alamaba, print out first all areas within first stop_reg climbing regions
content = soup.find_all('div',class_='mb-half')
counter = 0
stop = 0
stop_reg = 1
for c in content:
    if counter > stop:
        break
    else:
        curr = c.find('a')
        state_link = curr['href']
        state_page = urlopen(state_link)
        state_soup = BeautifulSoup(state_page,'html.parser')
        
        #get climbing regions within the state
        regions_content = state_soup.find_all('div',class_='lef-nav-row')
        #print(regions_content)
        
        state_name = state_soup.find('h1').get_text()
        print(state_name)
        counter_reg = 0
        for rc in regions_content:
            if counter_reg > stop_reg:
                break
            else:
                curr_region = rc.find('a')
                curr_region_text = curr_region.get_text()
                curr_region_link = curr_region['href']
                print('-',curr_region_text)
                
                region_page = urlopen(curr_region_link)
                region_soup = BeautifulSoup(region_page,'html.parser')
                
                #get climbing areas within region
                area_content = region_soup.find_all('div',class_='lef-nav-row')
                if counter_reg == 1:
                    print(area_content)
                    
                area_name = region_soup.find('h1').get_text()
                print('--',area_name)
                
                for ac in area_content:
                    curr_area = ac.find('a')
                    curr_area_text = curr_area.get_text()
                    curr_area_link = curr_area['href']
                    print('---',curr_area_text,curr_area_link)
                    
                time.sleep(1)
                
            counter_reg += 1
            
    counter += 1
# Out:
#     Alabama Climbing
#
#
# - BankHead Forest/ Thompson Creek Trail
# --
#     BankHead Forest/ Thompson Creek Trail Climbing
#
#
# --- Journey Area, The https://www.mountainproject.com/area/107605155/the-journey-area
# --- Will Robinson Area https://www.mountainproject.com/area/107605138/will-robinson-area
# - Bankhead Forest/Ship Rock
# []
# --
#     Bankhead Forest/Ship Rock Climbing

# %% [markdown]
# ## Put all together

# %%
from urllib.request import urlopen
from IPython.core.debugger import set_trace

#returns state/region/route area/route from tag with class name class_name

'''
input:
    soup: BeautifulSoup instance with html parser
    tag: html tag to find
    class_name: class name to find within tag
    id_name: id name of class
    stop_ind: routine returns first stop_ind 
    is_route_level: boolean, set to true if this level is the climbing routes
'''
def get_route_level_data(soup, tag, class_name, id_name='', stop_ind=-1, is_route_level=False):
    if not id_name:
        content = soup.find_all(tag,class_=class_name)
    else:
        content = soup.find_all(tag,class_=class_name,id=id_name)
    
    counter = 0
    
    link_list = []
    text_list = []
    for c in content:
        if is_route_level:
            #set_trace()
            routes = c.find_all('a')
            
            for r in routes:
                if stop_ind != -1:
                    if counter > stop_ind:
                        break
                
                curr_route_name = r.get_text()
                curr_route_link = r['href']
                
                link_list.append(curr_route_link)
                text_list.append(curr_route_name)
        else:
            if stop_ind != -1:
                if counter > stop_ind:
                    break
                    
            curr = c.find('a')
            curr_link = curr['href']
            curr_text = curr.get_text()
        
            link_list.append(curr_link)
            text_list.append(curr_text)
        
            counter += 1
        
    return content, link_list, text_list

# %%
from bs4 import BeautifulSoup
from IPython.core.debugger import set_trace
import time

route_page = 'https://www.mountainproject.com/route-guide'
page = urlopen(route_page)
soup = BeautifulSoup(page,'html.parser')

#get data for Alabama only
content_route_dir, link_route_dir, text_route_dir = get_route_level_data(soup,'div','mb-half',stop_ind=0)

for rdind in range(len(link_route_dir)):
    print(text_route_dir[rdind], link_route_dir[rdind])
    
    time.sleep(1)
    state_soup = BeautifulSoup(urlopen(link_route_dir[rdind]),'html.parser')
    
    #get data for climbing regions within state
    content_region, link_region, text_region = get_route_level_data(state_soup,'div','lef-nav-row',stop_ind=2)
    
    for regind in range(len(link_region)):
        print('\t',text_region[regind],link_region[regind])
        
        time.sleep(1)
        reg_soup = BeautifulSoup(urlopen(link_region[regind]),'html.parser')
        
        content_area, link_area, text_area = get_route_level_data(reg_soup,'div','lef-nav-row')
        
        #if content area is empty, check for routes instead
        if not content_area:
            #set_trace()
            content_route, link_route, text_route = get_route_level_data(reg_soup,'table','width100',id_name='left-nav-route-table',is_route_level=True)
                
            #set_trace()
            for routeind in range(len(text_route)):
                print('\t\t\t',text_route[routeind],link_route[routeind])
        else:
            for areaind in range(len(content_area)):
                print('\t\t',text_area[areaind],link_area[areaind])
                
                time.sleep(1)
                area_soup = BeautifulSoup(urlopen(link_area[areaind]),'html.parser')
                
                #set_trace()
                content_route, link_route, text_route = get_route_level_data(area_soup,'table','width100',id_name='left-nav-route-table',is_route_level=True)
                
                for routeind in range(len(text_route)):
                    print('\t\t\t',text_route[routeind],link_route[routeind])
# Out:
# Alabama https://www.mountainproject.com/area/105905173/alabama
# 	 BankHead Forest/ Thompson Creek Trail https://www.mountainproject.com/area/107605102/bankhead-forest-thompson-creek-trail
# 		 Journey Area, The https://www.mountainproject.com/area/107605155/the-journey-area
# 			 Fiery Ginger https://www.mountainproject.com/route/107605174/fiery-ginger
# 		 Will Robinson Area https://www.mountainproject.com/area/107605138/will-robinson-area
# 			 Bombs Away https://www.mountainproject.com/route/107717687/bombs-away
# 	 Bankhead Forest/Ship Rock https://www.mountainproject.com/area/106248455/bankhead-forestship-rock
# 			 "Stonyman" https://www.mountainproject.com/route/106248472/stonyman
# 			 Arrow Head https://www.mountainproject.com/route/106249536/arrow-head
# 			 Bubba https://www.mountainproject.com/route/106249545/bubba
# 			 Cutting Teeth https://www.mountainproject.com/route/106651430/cutting-teeth
# ...

# %% [markdown]
# ## TEST RECURSIVE SPIDER

# %%
    #given soup, find all data associated with class_name, id_name
    def get_route_level_data(soup, tag, class_name, id_name='', 
                             start_ind=0, stop_ind=-1, is_route_level=False):
        if not id_name:
            content = soup.find_all(tag,class_=class_name)
        else:
            content = soup.find_all(tag,class_=class_name,id=id_name)
        
        counter = 0
        
        link_list = []
        text_list = []
        for c in content:
            if is_route_level:
                #set_trace()
                routes = c.find_all('a')
                
                for r in routes:
                    if counter < start_ind:
                        continue
                    
                    if stop_ind != -1:
                        if counter > stop_ind:
                            break
                    
                    curr_route_name = r.get_text()
                    curr_route_link = r['href']
                    
                    link_list.append(curr_route_link)
                    text_list.append(curr_route_name)
            else:
                if stop_ind != -1:
                    if counter > stop_ind:
                        break
                        
                curr = c.find('a')
                curr_link = curr['href']
                curr_text = curr.get_text()
            
                link_list.append(curr_link)
                text_list.append(curr_text)
            
                counter += 1
            
        return content, link_list, text_list

# %%
def get_route_level_data_helper(soup, stop_ind=2):
    #set_trace()
    content_area, link_area, text_area = \
        get_route_level_data(soup,'div','lef-nav-row',stop_ind=stop_ind)
    
    content_route, link_route, text_route = \
        get_route_level_data(soup,'table','width100',id_name='left-nav-route-table',is_route_level=True,stop_ind=stop_ind)
    
    return content_area, link_area, text_area, content_route, link_route, text_route

# %%
from bs4 import BeautifulSoup
from IPython.core.debugger import set_trace
import time
from urllib.request import urlopen

def get_children(soup):
    content_area, link_area, text_area, \
        content_route, link_route, text_route = get_route_level_data_helper(soup,stop_ind=-1)
    #set_trace()
    if link_area:
        #print(link_area)
        
        link_master = []
        text_master = []
    
        for laind in range(len(link_area)):            
            time.sleep(0.01)
            curr_soup = BeautifulSoup(urlopen(link_area[laind]),'html.parser')
            
            #set_trace()
            
            [link, text] = get_children(curr_soup)
            link_master.append([link_area[laind], link])
            text_master.append([text_area[laind], text])
            
        return [link_master, text_master]
    
    if link_route:
        return [link_route, text_route]
    else:
        return None

# %%
soup = BeautifulSoup(urlopen('https://www.mountainproject.com/area/106225748/olmsted-area'),'html.parser')
start = time.time()
[route_link,route_name] = get_children(soup)
end = time.time()
print('time',end-start)
# Out:
# time 6.65471625328064

# %%
route_link
# Out:
# [['https://www.mountainproject.com/area/106673053/clouds-rest',
#   [['https://www.mountainproject.com/area/115361709/west-face',
#     ['https://www.mountainproject.com/route/106673057/my-favorite-things']]]],
#  ['https://www.mountainproject.com/area/117122747/moya-wall',
#   ['https://www.mountainproject.com/route/117122946/eatin-air',
#    'https://www.mountainproject.com/route/117638111/just-like-a-vagina',
#    'https://www.mountainproject.com/route/117637809/moya',
#    'https://www.mountainproject.com/route/117637573/ten-b-or-not-ten-b']],
#  ['https://www.mountainproject.com/area/110824974/olmsted-canyon-left',
#   ['https://www.mountainproject.com/route/109892110/black-like-me',
#    'https://www.mountainproject.com/route/106672951/creature-from-the-black-lagoon']],
#  ['https://www.mountainproject.com/area/110824990/olmsted-canyon-right',
#   ['https://www.mountainproject.com/route/109353083/age-of-darkness',
# ...

# %%
    def get_children(soup,start_ind=0,stop_ind=-1,is_root=False):
        if is_root:
            content_area, link_area, text_area, \
                content_route, link_route, text_route = \
                    get_route_level_data_helper(soup,stop_ind=stop_ind)
        else:
            content_area, link_area, text_area, \
                content_route, link_route, text_route = \
                    get_route_level_data_helper(soup,stop_ind=-1)
                    
        #set_trace()
        if link_area:
            #print(link_area)
            
            link_master = []
            text_master = []
            id_master = []
        
            for laind in range(len(link_area)):            
                time.sleep(0.0001)
                curr_soup = BeautifulSoup(urlopen(link_area[laind]),'html.parser')
                
                #set_trace()
                
                [link, text, mpid] = get_children(curr_soup)
                link_master.append([link_area[laind], link])
                text_master.append([text_area[laind], text])
                id_master.append([get_id(link_area[laind]), mpid])
                
            return [link_master, text_master, id_master]
        
        if link_route:
            return [link_route, text_route, get_id(link_route)]
        else:
            return None
        
    #extract route of area id from MP URL
    def get_id(link):
        if len(link) == 1:    
            sep = link.split('/')
            
            return sep[-2] #id is always 2nd to last in this delimiter
        elif len(link) > 1:
            ids = []
            set_trace()
            for curr_link in link:
                sep = curr_link.split('/')
                ids.append(sep[-2])
                
            return ids

# %%
soup = BeautifulSoup(urlopen('https://www.mountainproject.com/area/106225748/olmsted-area'),'html.parser')
start = time.time()
[route_link,route_name,route_id] = get_children(soup)
end = time.time()
print('time',end-start)

# %%
from MP_Scraper import MP_Scraper
mps = MP_Scraper('https://www.mountainproject.com/area/107676024/galens-crack',verbatim=True,urlopen_delay=0.0)
mps.scrape_MP()
# Out:
# ["Galen's Crack"]
# time elapsed =  0.0459742546081543
# --Return--
# None
# > c:\users\george\documents\ml_sandbox\mp_scraper\mp_scraper.py(228)scrape_MP()
#     226
#     227         ids,route_links = self.get_all_route_ids_links(route_link)
# --> 228         set_trace()
#     229
#     230     def find_master_area(self, dirurl = 'https://www.mountainproject.com/route-guide'):
#
# ipdb> ids
# [107676048]
# ipdb> route_links
# ['https://www.mountainproject.com/route/107676048/galens-crack']
# ipdb> exit()
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-2-9acd101ec5fb> in <module>
#       1 from MP_Scraper import MP_Scraper
#       2 mps = MP_Scraper('https://www.mountainproject.com/area/107676024/galens-crack',verbatim=True,urlopen_delay=0.0)
# ----> 3 mps.scrape_MP()
#
# ~\Documents\ML_SANDBOX\MP_Scraper\MP_Scraper.py in scrape_MP(self)
#     226
# ...

# %%
(((13/18)*30704)/60)/60
# Out:
# 6.1597530864197525

# %%
# %debug
# Out:
# > c:\users\george\documents\ml_sandbox\mp_scraper\mp_scraper.py(188)get_children()
#     186                 #set_trace()
#     187
# --> 188                 [link, text] = self.get_children(curr_soup)
#     189                 link_master.append([link_area[laind], link])
#     190                 text_master.append([text_area[laind], text])
#
# ipdb> [link, text] = self.get_children(curr_soup)
# *** TypeError: cannot unpack non-iterable NoneType object
# ipdb> link_area[laind]
# 'https://www.mountainproject.com/area/108533355/little-eastatoee'
# ipdb> link_master
# []
# ipdb> link_area
# ['https://www.mountainproject.com/area/108533355/little-eastatoee']
# ipdb> laind
# 0
# ipdb> link_area == ['['https://www.mountainproject.com/area/108533355/little-eastatoee']
# *** SyntaxError: invalid syntax
# ipdb> link_area == ['https://www.mountainproject.com/area/108533355/little-eastatoee']
# True
# ipdb> exit()

# %% [markdown]
# ## SQL TEST

# %%
import sqlalchemy as db
engine = db.create_engine('postgresql://postgres:hmnigls209@localhost/MountainProjectData')
connection = engine.connect()
metadata = db.MetaData()
routes_table = db.Table('routes', metadata, autoload=True, autoload_with=engine)

# %%
from MP_Scraper import MP_Scraper

with open('MountainProjectData_db_pw.ini', 'r') as content_file:
    pw = content_file.read()

db_address = 'postgresql://postgres:'+pw+'@localhost/MountainProjectData'
    
mps = MP_Scraper('https://www.mountainproject.com/area/110824974/olmsted-canyon-left',db_address,verbatim=True,urlopen_delay=0.0)
mps.scrape_MP()
# Out:
# ['Black Like Me', 'Creature from the Black Lagoon']
# time elapsed =  0.018008947372436523
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-298b7a277d84> in <module>
#       7
#       8 mps = MP_Scraper('https://www.mountainproject.com/area/110824974/olmsted-canyon-left',db_address,verbatim=True,urlopen_delay=0.0)
# ----> 9 mps.scrape_MP()
#
# ~\Documents\ML_SANDBOX\MP_Scraper\MP_Scraper.py in scrape_MP(self)
#     236         routes_table = db.Table('routes', self.metadata, autoload=True, autoload_with=self.engine)
#     237         query = db.insert(routes_table,bind=self.engine)
# --> 238         query = query.on_conflict_do_nothing(index_elements=['route_id'])
#     239         self.connection.execute(query,[{'route_id': id_} for id_ in ids])
#     240
#
# AttributeError: 'Insert' object has no attribute 'on_conflict_do_nothing'

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

soup = BeautifulSoup(urlopen('https://www.mountainproject.com/route/106672951/creature-from-the-black-lagoon'),'html.parser')
        
content = soup.find('h1')
route_name = content.get_text().strip()
# Out:
#         Creature from the Black Lagoon

# %%
import requests
import json

url = 'https://www.mountainproject.com/data/get-routes?routeIds=106637286&key=200128311-828e565741df5f894fbae7929cfa995e'

r = requests.get(url)
data = r.json()
# Out:
# {'routes': [{'id': 106637286, 'name': 'North Face North Couloir (right couloir)', 'type': 'Ice, Snow, Alpine', 'rating': 'AI2 Steep Snow', 'stars': 4.4, 'starVotes': 53, 'pitches': 6, 'location': ['California', 'High Sierra', '01 - Hoover Wilderness', 'North Peak'], 'url': 'https://www.mountainproject.com/route/106637286/north-face-north-couloir-right-couloir', 'imgSqSmall': 'https://cdn-files.apstatic.com/climb/112163615_sqsmall_1494324644.jpg', 'imgSmall': 'https://cdn-files.apstatic.com/climb/112163615_small_1494324644.jpg', 'imgSmallMed': 'https://cdn-files.apstatic.com/climb/112163615_smallMed_1494324644.jpg', 'imgMedium': 'https://cdn-files.apstatic.com/climb/112163615_medium_1494324644.jpg', 'longitude': -119.3146, 'latitude': 37.9822}], 'success': 1}

# %%
from MP_Scraper import MP_Scraper

with open('MountainProjectData_db_pw.ini', 'r') as content_file:
    pw = content_file.read()
    
with open('MP_api_key.ini','r') as content_file:
    api_key = content_file.read()

db_address = 'postgresql://postgres:'+pw+'@localhost/MountainProjectData'
    
mps = MP_Scraper('https://www.mountainproject.com/area/110824974/olmsted-canyon-left',db_address,api_key,\
                 verbatim=True,urlopen_delay=0.0)
mps.scrape_MP()
# Out:
# ['Black Like Me', 'Creature from the Black Lagoon']
# time elapsed =  0.0159914493560791
# --Return--
# None
# > c:\users\george\documents\ml_sandbox\mp_scraper\mp_scraper.py(253)scrape_MP()
#     251         self.engine.dispose()
#     252
# --> 253         set_trace()
#     254
#     255     #TODO
#
# ipdb> exit()
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-1-8d0575c642c2> in <module>
#      11 mps = MP_Scraper('https://www.mountainproject.com/area/110824974/olmsted-canyon-left',db_address,api_key,\
#      12                  verbatim=True,urlopen_delay=0.0)
# ---> 13 mps.scrape_MP()
#
# ~\Documents\ML_SANDBOX\MP_Scraper\MP_Scraper.py in scrape_MP(self)
#     251         self.engine.dispose()
#     252
# --> 253         set_trace()
#     254
#     255     #TODO
#
# ~\Anaconda3\lib\bdb.py in trace_dispatch(self, frame, event, arg)
# ...

# %%
link = 'https://www.mountainproject.com/route/106637286/north-face-north-couloir-right-couloir'
print(link.split('/'))
print(link[37])
print(link[:37]+'/stats'+link[37:])
# Out:
# ['https:', '', 'www.mountainproject.com', 'route', '106637286', 'north-face-north-couloir-right-couloir']
# /
# https://www.mountainproject.com/route/stats/106637286/north-face-north-couloir-right-couloir

# %%
from bs4 import BeautifulSoup
import requests

r = requests.get('https://www.mountainproject.com/route/stats/106637286/north-face-north-couloir-right-couloir')

soup = BeautifulSoup(r.text,'html5lib')
        
content = soup.find('table',\
                   class_='table table-striped')

table_rows = content.find_all('tr')

user_link = []
nstars = []
for i in range(len(table_rows)):
    table_data = table_rows[i].find_all('td')
    
    user_link.append(table_data[0].find('a')['href'])
    
    nstars.append(len(table_data[1].find_all('img')))

# %%
import pandas as pd
df=pd.DataFrame({'user link': user_link, 'star rating':nstars})
df
# Out:
#                                             user link  star rating
# 0   https://www.mountainproject.com/user/111379256...            4
# 1   https://www.mountainproject.com/user/107780599...            4
# 2   https://www.mountainproject.com/user/110049722...            4
# 3   https://www.mountainproject.com/user/106095990...            4
# 4   https://www.mountainproject.com/user/111585366...            4
# 5   https://www.mountainproject.com/user/200095215...            4
# 6   https://www.mountainproject.com/user/111366962...            4
# 7   https://www.mountainproject.com/user/107392044...            4
# 8   https://www.mountainproject.com/user/111756555...            4
# 9   https://www.mountainproject.com/user/108815306...            4
# 10  https://www.mountainproject.com/user/106885514...            4
# 11  https://www.mountainproject.com/user/105947198...            4
# 12  https://www.mountainproject.com/user/11470/tyl...            4
# ...

# %%
from MP_Scraper import MP_Scraper

with open('MountainProjectData_db_pw.ini', 'r') as content_file:
    pw = content_file.read()
    
with open('MP_api_key.ini','r') as content_file:
    api_key = content_file.read()

db_address = 'postgresql://postgres:'+pw+'@localhost/MountainProjectData'
    
mps = MP_Scraper('https://www.mountainproject.com/area/105733890/castle-rock-area',db_address,api_key,verbatim=True,urlopen_delay=0.0001)
mps.scrape_MP()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b6b1472df9d2> in <module>
#      10
#      11 mps = MP_Scraper('https://www.mountainproject.com/area/105733890/castle-rock-area',db_address,api_key,verbatim=True,urlopen_delay=0.01)
# ---> 12 mps.scrape_MP()
#
# ~\Documents\ML_SANDBOX\MP_Scraper\MP_Scraper.py in scrape_MP(self)
#     237
#     238         start = time.time()
# --> 239         [route_link,route_name] = self.get_children(self.root_soup)
#     240         end = time.time()
#     241
#
# ~\Documents\ML_SANDBOX\MP_Scraper\MP_Scraper.py in get_children(self, soup, start_ind, stop_ind, is_root)
#     209             for laind in range(len(link_area)):
#     210                 time.sleep(self.urlopen_delay)
# --> 211                 curr_soup = BeautifulSoup(urlopen(link_area[laind]),'html.parser')
#     212
#     213                 #set_trace()
#
# ...

# %%
# %debug
# Out:
# > c:\users\george\documents\ml_sandbox\mp_scraper\mp_scraper.py(370)get_users_who_rated_route()
#     368             user_star_rating = len(table_data[1].find_all('img'))
#     369
# --> 370             self.user_id_dict[user_id][route_id] = user_star_rating
#     371
#     372             #the corresponding user star rating of route
#
# ipdb> user_id
# 109446305
# ipdb> route_id
# 106388637
# ipdb> self.user_id_dict[user_id]
# *** KeyError: 109446305
# ipdb> self.user_id_dict[1] = {}
# ipdb> self.user_id_dict[1][2322] = 3
# ipdb> self.user_id_dict[1][333] =2
# ipdb> self.user_id_dict[1]
# {2322: 3, 333: 2}
# ipdb> exit()

# %%
from bs4 import BeautifulSoup
import requests

r = requests.get('https://www.mountainproject.com/route/116385893/green-sponge')
soup = BeautifulSoup(r.text,'html5lib')

content = soup.find('table',class_='description-details')

# %%
c = content.find_all('td')[1]
c = c.get_text().strip()
sp = c.split(',')
sp = sp[-1].split()
grade = None
if sp[0] == 'Grade':
    grade = sp[1]
    if grade == 'I':
        num_grade = 1
    elif grade == 'II':
        num_grade = 2
    elif grade == 'III':
        num_grade = 3
    elif grade == 'IV':
        num_grade = 4
    elif grade == 'V':
        num_grade = 5
    elif grade == 'VI':
        num_grade = 6
    else:
        num_grade = None
else:
    num_grade = None

print(sp)
print(num_grade)
# Out:
# ['7', 'pitches']
# None
